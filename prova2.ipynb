# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.datasets import electrocardiogram
import scipy
import sys
sys.setrecursionlimit(10**9)

# %%
x = electrocardiogram()[2000:4000]
peaks = scipy.signal.find_peaks(x)
plt.plot(x)
plt.plot(peaks, x[peaks], "x")
plt.plot(np.zeros_like(x), "--", color="gray")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[11], line 2
#       1 x = electrocardiogram()[2000:4000]
# ----> 2 peaks = scipy.signal.find_peaks(x, height=0)
#       3 plt.plot(x)
#       4 plt.plot(peaks, x[peaks], "x")
#
# File ~/miniconda3/envs/VoyagerImages/lib/python3.12/site-packages/scipy/__init__.py:134, in __getattr__(name)
#     132 def __getattr__(name):
#     133     if name in submodules:
# --> 134         return _importlib.import_module(f'scipy.{name}')
#     135     else:
#     136         try:
#
# File ~/miniconda3/envs/VoyagerImages/lib/python3.12/importlib/__init__.py:90, in import_module(name, package)
#      88             break
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1331, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:935, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:995, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:488, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~/miniconda3/envs/VoyagerImages/lib/python3.12/site-packages/scipy/signal/__init__.py:320
#     310 from ._upfirdn import upfirdn
#     312 from ._spline import (
#     313     cspline2d,
#     314     qspline2d,
#    (...)
#     317     symiirorder2,
#     318 )
# --> 320 from ._bsplines import *
#     321 from ._filter_design import *
#     322 from ._fir_filter_design import *
#
# File ~/miniconda3/envs/VoyagerImages/lib/python3.12/site-packages/scipy/signal/_bsplines.py:7
#       5 # From splinemodule.c
#       6 from ._spline import cspline2d, sepfir2d
# ----> 7 from ._signaltools import lfilter, sosfilt, lfiltic
#       9 from scipy.interpolate import BSpline
#      11 __all__ = ['spline_filter', 'gauss_spline',
#      12            'cspline1d', 'qspline1d', 'cspline1d_eval', 'qspline1d_eval']
#
# File ~/miniconda3/envs/VoyagerImages/lib/python3.12/site-packages/scipy/signal/_signaltools.py:16
#      14 from scipy.spatial import cKDTree
#      15 from . import _sigtools
# ---> 16 from ._ltisys import dlti
#      17 from ._upfirdn import upfirdn, _output_len, _upfirdn_modes
#      18 from scipy import linalg, fft as sp_fft
#
# File ~/miniconda3/envs/VoyagerImages/lib/python3.12/site-packages/scipy/signal/_ltisys.py:29
#      27 from scipy.linalg import qr as s_qr
#      28 from scipy import linalg
# ---> 29 from scipy.interpolate import make_interp_spline
#      30 from ._filter_design import (tf2zpk, zpk2tf, normalize, freqs, freqz, freqs_zpk,
#      31                             freqz_zpk)
#      32 from ._lti_conversion import (tf2ss, abcd_normalize, ss2tf, zpk2ss, ss2zpk,
#      33                              cont2discrete, _atleast_2d_or_none)
#
# File ~/miniconda3/envs/VoyagerImages/lib/python3.12/site-packages/scipy/interpolate/__init__.py:167
#       1 """
#       2 ========================================
#       3 Interpolation (:mod:`scipy.interpolate`)
#    (...)
#     165 (should not be used in new code).
#     166 """
# --> 167 from ._interpolate import *
#     168 from ._fitpack_py import *
#     170 # New interface to fitpack library:
#
# File ~/miniconda3/envs/VoyagerImages/lib/python3.12/site-packages/scipy/interpolate/_interpolate.py:12
#       9 from scipy._lib._util import copy_if_needed
#      10 from scipy.special import comb
# ---> 12 from . import _fitpack_py
#      13 from ._polyint import _Interpolator1D
#      14 from . import _ppoly
#
# File ~/miniconda3/envs/VoyagerImages/lib/python3.12/site-packages/scipy/interpolate/_fitpack_py.py:8
#       5 import numpy as np
#       7 # These are in the API for fitpack even if not used in fitpack.py itself.
# ----> 8 from ._fitpack_impl import bisplrep, bisplev, dblint  # noqa: F401
#       9 from . import _fitpack_impl as _impl
#      10 from ._bsplines import BSpline
#
# File ~/miniconda3/envs/VoyagerImages/lib/python3.12/site-packages/scipy/interpolate/_fitpack_impl.py:103
#      52 _iermess = {
#      53     0: ["The spline has a residual sum of squares fp such that "
#      54         "abs(fp-s)/s<=0.001", None],
#    (...)
#      68     'unknown': ["An error occurred", TypeError]
#      69 }
#      71 _iermess2 = {
#      72     0: ["The spline has a residual sum of squares fp such that "
#      73         "abs(fp-s)/s<=0.001", None],
#    (...)
#      99     'unknown': ["An error occurred", TypeError]
#     100 }
#     102 _parcur_cache = {'t': array([], float), 'wrk': array([], float),
# --> 103                  'iwrk': array([], dfitpack_int), 'u': array([], float),
#     104                  'ub': 0, 'ue': 1}
#     107 def splprep(x, w=None, u=None, ub=None, ue=None, k=3, task=0, s=None, t=None,
#     108             full_output=0, nest=None, per=0, quiet=1):
#     109     # see the docstring of `_fitpack_py/splprep`
#     110     if task <= 0:
#
# File ~/miniconda3/envs/VoyagerImages/lib/python3.12/site-packages/numpy/core/_dtype.py:46, in __repr__(dtype)
#      45 def __repr__(dtype):
# ---> 46     arg_str = _construction_repr(dtype, include_align=False)
#      47     if dtype.isalignedstruct:
#      48         arg_str = arg_str + ", align=True"
#
# File ~/miniconda3/envs/VoyagerImages/lib/python3.12/site-packages/numpy/core/_dtype.py:100, in _construction_repr(dtype, include_align, short)
#      98     return _subarray_str(dtype)
#      99 else:
# --> 100     return _scalar_str(dtype, short=short)
#
# File ~/miniconda3/envs/VoyagerImages/lib/python3.12/site-packages/numpy/core/_dtype.py:143, in _scalar_str(dtype, short)
#     140 elif dtype.type == np.timedelta64:
#     141     return "'%sm8%s'" % (byteorder, _datetime_metadata_str(dtype))
# --> 143 elif np.issubdtype(dtype, np.number):
#     144     # Short repr with endianness, like '<f8'
#     145     if short or dtype.byteorder not in ('=', '|'):
#     146         return "'%s%c%d'" % (byteorder, dtype.kind, dtype.itemsize)
#
# File ~/miniconda3/envs/VoyagerImages/lib/python3.12/site-packages/numpy/core/numerictypes.py:417, in issubdtype(arg1, arg2)
#     359 r"""
#     360 Returns True if first argument is a typecode lower/equal in type hierarchy.
#     361
#    (...)
#     414
#     415 """
#     416 if not issubclass_(arg1, generic):
# --> 417     arg1 = dtype(arg1).type
#     418 if not issubclass_(arg2, generic):
#     419     arg2 = dtype(arg2).type
#
# File ~/miniconda3/envs/VoyagerImages/lib/python3.12/site-packages/numpy/core/_dtype.py:46, in __repr__(dtype)
#      45 def __repr__(dtype):
# ---> 46     arg_str = _construction_repr(dtype, include_align=False)
#      47     if dtype.isalignedstruct:
#      48         arg_str = arg_str + ", align=True"
#
# File ~/miniconda3/envs/VoyagerImages/lib/python3.12/site-packages/numpy/core/_dtype.py:100, in _construction_repr(dtype, include_align, short)
#      98     return _subarray_str(dtype)
#      99 else:
# --> 100     return _scalar_str(dtype, short=short)
#
# File ~/miniconda3/envs/VoyagerImages/lib/python3.12/site-packages/numpy/core/_dtype.py:143, in _scalar_str(dtype, short)
#     140 elif dtype.type == np.timedelta64:
#     141     return "'%sm8%s'" % (byteorder, _datetime_metadata_str(dtype))
# --> 143 elif np.issubdtype(dtype, np.number):
#     144     # Short repr with endianness, like '<f8'
#     145     if short or dtype.byteorder not in ('=', '|'):
#     146         return "'%s%c%d'" % (byteorder, dtype.kind, dtype.itemsize)
#
# File ~/miniconda3/envs/VoyagerImages/lib/python3.12/site-packages/numpy/core/numerictypes.py:417, in issubdtype(arg1, arg2)
#     359 r"""
#     360 Returns True if first argument is a typecode lower/equal in type hierarchy.
#     361
#    (...)
#     414
#     415 """
#     416 if not issubclass_(arg1, generic):
# --> 417     arg1 = dtype(arg1).type
#     418 if not issubclass_(arg2, generic):
#     419     arg2 = dtype(arg2).type
#
#     [... skipping similar frames: __repr__ at line 46 (2482 times), _construction_repr at line 100 (2482 times), _scalar_str at line 143 (2482 times), issubdtype at line 417 (2482 times)]
#
# File ~/miniconda3/envs/VoyagerImages/lib/python3.12/site-packages/numpy/core/_dtype.py:46, in __repr__(dtype)
#      45 def __repr__(dtype):
# ---> 46     arg_str = _construction_repr(dtype, include_align=False)
#      47     if dtype.isalignedstruct:
#      48         arg_str = arg_str + ", align=True"
#
# File ~/miniconda3/envs/VoyagerImages/lib/python3.12/site-packages/numpy/core/_dtype.py:100, in _construction_repr(dtype, include_align, short)
#      98     return _subarray_str(dtype)
#      99 else:
# --> 100     return _scalar_str(dtype, short=short)
#
# File ~/miniconda3/envs/VoyagerImages/lib/python3.12/site-packages/numpy/core/_dtype.py:143, in _scalar_str(dtype, short)
#     140 elif dtype.type == np.timedelta64:
#     141     return "'%sm8%s'" % (byteorder, _datetime_metadata_str(dtype))
# --> 143 elif np.issubdtype(dtype, np.number):
#     144     # Short repr with endianness, like '<f8'
#     145     if short or dtype.byteorder not in ('=', '|'):
#     146         return "'%s%c%d'" % (byteorder, dtype.kind, dtype.itemsize)
#
# File ~/miniconda3/envs/VoyagerImages/lib/python3.12/site-packages/numpy/core/numerictypes.py:417, in issubdtype(arg1, arg2)
#     359 r"""
#     360 Returns True if first argument is a typecode lower/equal in type hierarchy.
#     361
#    (...)
#     414
#     415 """
#     416 if not issubclass_(arg1, generic):
# --> 417     arg1 = dtype(arg1).type
#     418 if not issubclass_(arg2, generic):
#     419     arg2 = dtype(arg2).type
#
# RecursionError: maximum recursion depth exceeded while calling a Python object
# Normalization failed: type=AttributeError args=<unknown>
